# %%
import sys

# Get the path to the helper functions
sys.path.append('../src/')

import importlib
import read_data.helper as helper

# Reload helper functions
importlib.reload(helper)
# Out:
# <module 'read_data.helper' from '/Users/rukundong/SDA25_Group11/notebook/../src/read_data/helper.py'>

# %%
df = helper.load_16M_tweet(columns=["timestamp", "text"], csv_path="../data/tweets.csv")
print(df.head(2))
# Out:
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ timestamp           ┆ text                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2019-05-27 11:49:14 ┆ È appena uscito un nuovo video… │
# │ 2019-05-27 11:49:18 ┆ Cardano: Digitize Currencies; … │
# └─────────────────────┴─────────────────────────────────┘
