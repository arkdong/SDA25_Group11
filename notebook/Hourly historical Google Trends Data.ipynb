# %% [markdown]
# This is code obtained from https://github.com/BastianF/Hourly-historical-Google-Trends-Data/blob/master/Hourly%20historical%20Google%20Trends%20Data.ipynb and modified to fit 'bitcoin' search results in 2018.

# %% [markdown]
# # Get hourly Google Trends Data for (Time Series) Analysis via Python API
#
# Google Trends is a service which provides meaningful insights on relative search requests on Google. The data can be accessed via the webside https://trends.google.com or Python/R API. In this tutorial I ll show you how to process the data via Python API to get historical and hourly long term Google Trends data.
#
# Google will return relative values between 0 and 100 for your query of an specific keyword. Whereas 0 means lowest search volumne and 100 the highest. A challange I experienced was that that the API returns only about 200 data points for your specified time period. That means if you querie data for one year, you will get about 200 data points, resulting in one data point every 365/~200 days which is scaled from 0 to 100. If you want hourly data, you need to query timeframes, which have about 200 data points and combine them - for example one week = 7*24 = 168 data points. But since your data will be scaled from 0 to 100 for each week of your query, your overall scaling will be wrong. That means, you can not get hourly and correctly scaled trends data for longer time periods without further processing. To get the correct scaling you need to overlap the weeks and calculate a ratio with which you will obtain the proper scaling.

# %%
import datetime
from pytrends.request import TrendReq # pip install pytrends - Written for both Python 2.7+ and Python 3.3+
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""Specify start and end date as well es the requiered keyword for your query"""
start_date = datetime.date(2018, 1, 1)
end_date = datetime.date(2019, 1, 1)
keyword_list = ["bitcoin"] # If you add a second string, minor adjustments in the code have to be made

# %%
"""Since we want weekly data for our query, we will create lists which include 
the weekly start and end date in the specified timeframe - 2018.01.01 to 2019.5.01"""

weekly_date_list = []

#Adds the start date as first entry in our weekly_date_list
start_date_temp = start_date
weekly_date_list.append(start_date_temp)

#This will return in list of weekly datetime.date objects - except the end date
while start_date_temp+datetime.timedelta(days=7) <= end_date:
    start_date_temp += datetime.timedelta(days=7)
    weekly_date_list.append(start_date_temp)

#This will add the end date to the weekly_date list. We now have a complete list in the specified timeframe
if start_date_temp+datetime.timedelta(days=7) > end_date:
    weekly_date_list.append(end_date)

# %%
weekly_date_list
# Out:
# [datetime.date(2018, 1, 1),
#  datetime.date(2018, 1, 8),
#  datetime.date(2018, 1, 15),
#  datetime.date(2018, 1, 22),
#  datetime.date(2018, 1, 29),
#  datetime.date(2018, 2, 5),
#  datetime.date(2018, 2, 12),
#  datetime.date(2018, 2, 19),
#  datetime.date(2018, 2, 26),
#  datetime.date(2018, 3, 5),
#  datetime.date(2018, 3, 12),
#  datetime.date(2018, 3, 19),
#  datetime.date(2018, 3, 26),
#  datetime.date(2018, 4, 2),
#  datetime.date(2018, 4, 9),
#  datetime.date(2018, 4, 16),
#  datetime.date(2018, 4, 23),
#  datetime.date(2018, 4, 30),
#  datetime.date(2018, 5, 7),
#  datetime.date(2018, 5, 14),
#  datetime.date(2018, 5, 21),
#  datetime.date(2018, 5, 28),
#  datetime.date(2018, 6, 4),
#  datetime.date(2018, 6, 11),
#  datetime.date(2018, 6, 18),
#  datetime.date(2018, 6, 25),
#  datetime.date(2018, 7, 2),
#  datetime.date(2018, 7, 9),
#  datetime.date(2018, 7, 16),
#  datetime.date(2018, 7, 23),
#  datetime.date(2018, 7, 30),
#  datetime.date(2018, 8, 6),
#  datetime.date(2018, 8, 13),
#  datetime.date(2018, 8, 20),
#  datetime.date(2018, 8, 27),
#  datetime.date(2018, 9, 3),
#  datetime.date(2018, 9, 10),
#  datetime.date(2018, 9, 17),
#  datetime.date(2018, 9, 24),
#  datetime.date(2018, 10, 1),
#  datetime.date(2018, 10, 8),
#  datetime.date(2018, 10, 15),
#  datetime.date(2018, 10, 22),
#  datetime.date(2018, 10, 29),
#  datetime.date(2018, 11, 5),
#  datetime.date(2018, 11, 12),
#  datetime.date(2018, 11, 19),
#  datetime.date(2018, 11, 26),
#  datetime.date(2018, 12, 3),
#  datetime.date(2018, 12, 10),
#  datetime.date(2018, 12, 17),
#  datetime.date(2018, 12, 24),
#  datetime.date(2018, 12, 31),
#  datetime.date(2019, 1, 1)]

# %%
"""Now we can start to downloading the data via Google Trends API
therefore we have to specify a key which includes the start date
and the end-date with T00 as string for hourly data request"""

#This List will contain pandas Dataframes of weekly data with the features "date",
#"keyword"(which contains weekly scaling bettwen 0 and 100), "isPartial".
#Up to this point, the scaling is not correct.
interest_list = []

#Here we download the data and print the current status of the process
for i in range(len(weekly_date_list)-1):
    key =str(weekly_date_list[i])+"T00 "+str(weekly_date_list[i+1])+"T00"
    p = TrendReq(retries=3)
    p.build_payload(kw_list=keyword_list, timeframe=key)
    interest=p.interest_over_time()
    interest_list.append(interest)
    print("GoogleTrends Call {} of {} : Timeframe: {} "\
          .format(i+1, len(weekly_date_list)-1, key )
          )
# Out:
# loop
# GoogleTrends Call 1 of 53 : Timeframe: 2018-01-01T00 2018-01-08T00
# loop
# GoogleTrends Call 2 of 53 : Timeframe: 2018-01-08T00 2018-01-15T00
# loop
# GoogleTrends Call 3 of 53 : Timeframe: 2018-01-15T00 2018-01-22T00
# loop
# GoogleTrends Call 4 of 53 : Timeframe: 2018-01-22T00 2018-01-29T00
# loop
# GoogleTrends Call 5 of 53 : Timeframe: 2018-01-29T00 2018-02-05T00
# loop
# GoogleTrends Call 6 of 53 : Timeframe: 2018-02-05T00 2018-02-12T00
# loop
# GoogleTrends Call 7 of 53 : Timeframe: 2018-02-12T00 2018-02-19T00
# loop
# GoogleTrends Call 8 of 53 : Timeframe: 2018-02-19T00 2018-02-26T00
# loop
# GoogleTrends Call 9 of 53 : Timeframe: 2018-02-26T00 2018-03-05T00
# loop
# GoogleTrends Call 10 of 53 : Timeframe: 2018-03-05T00 2018-03-12T00
# loop
# GoogleTrends Call 11 of 53 : Timeframe: 2018-03-12T00 2018-03-19T00
# loop
# GoogleTrends Call 12 of 53 : Timeframe: 2018-03-19T00 2018-03-26T00
# loop
# GoogleTrends Call 13 of 53 : Timeframe: 2018-03-26T00 2018-04-02T00
# loop
# GoogleTrends Call 14 of 53 : Timeframe: 2018-04-02T00 2018-04-09T00
# loop
# GoogleTrends Call 15 of 53 : Timeframe: 2018-04-09T00 2018-04-16T00
# loop
# GoogleTrends Call 16 of 53 : Timeframe: 2018-04-16T00 2018-04-23T00
# loop
# GoogleTrends Call 17 of 53 : Timeframe: 2018-04-23T00 2018-04-30T00
# loop
# GoogleTrends Call 18 of 53 : Timeframe: 2018-04-30T00 2018-05-07T00
# loop
# GoogleTrends Call 19 of 53 : Timeframe: 2018-05-07T00 2018-05-14T00
# loop
# GoogleTrends Call 20 of 53 : Timeframe: 2018-05-14T00 2018-05-21T00
# loop
# GoogleTrends Call 21 of 53 : Timeframe: 2018-05-21T00 2018-05-28T00
# loop
# GoogleTrends Call 22 of 53 : Timeframe: 2018-05-28T00 2018-06-04T00
# loop
# GoogleTrends Call 23 of 53 : Timeframe: 2018-06-04T00 2018-06-11T00
# loop
# GoogleTrends Call 24 of 53 : Timeframe: 2018-06-11T00 2018-06-18T00
# loop
# GoogleTrends Call 25 of 53 : Timeframe: 2018-06-18T00 2018-06-25T00
# loop
# GoogleTrends Call 26 of 53 : Timeframe: 2018-06-25T00 2018-07-02T00
# loop
# GoogleTrends Call 27 of 53 : Timeframe: 2018-07-02T00 2018-07-09T00
# loop
# GoogleTrends Call 28 of 53 : Timeframe: 2018-07-09T00 2018-07-16T00
# loop
# GoogleTrends Call 29 of 53 : Timeframe: 2018-07-16T00 2018-07-23T00
# loop
# GoogleTrends Call 30 of 53 : Timeframe: 2018-07-23T00 2018-07-30T00
# loop
# GoogleTrends Call 31 of 53 : Timeframe: 2018-07-30T00 2018-08-06T00
# loop
# GoogleTrends Call 32 of 53 : Timeframe: 2018-08-06T00 2018-08-13T00
# loop
# GoogleTrends Call 33 of 53 : Timeframe: 2018-08-13T00 2018-08-20T00
# loop
# GoogleTrends Call 34 of 53 : Timeframe: 2018-08-20T00 2018-08-27T00
# loop
# GoogleTrends Call 35 of 53 : Timeframe: 2018-08-27T00 2018-09-03T00
# loop
# GoogleTrends Call 36 of 53 : Timeframe: 2018-09-03T00 2018-09-10T00
# loop
# GoogleTrends Call 37 of 53 : Timeframe: 2018-09-10T00 2018-09-17T00
# loop
# GoogleTrends Call 38 of 53 : Timeframe: 2018-09-17T00 2018-09-24T00
# loop
# GoogleTrends Call 39 of 53 : Timeframe: 2018-09-24T00 2018-10-01T00
# loop
# GoogleTrends Call 40 of 53 : Timeframe: 2018-10-01T00 2018-10-08T00
# loop
# GoogleTrends Call 41 of 53 : Timeframe: 2018-10-08T00 2018-10-15T00
# loop
# GoogleTrends Call 42 of 53 : Timeframe: 2018-10-15T00 2018-10-22T00
# loop
# GoogleTrends Call 43 of 53 : Timeframe: 2018-10-22T00 2018-10-29T00
# loop
# GoogleTrends Call 44 of 53 : Timeframe: 2018-10-29T00 2018-11-05T00
# loop
# GoogleTrends Call 45 of 53 : Timeframe: 2018-11-05T00 2018-11-12T00
# loop
# GoogleTrends Call 46 of 53 : Timeframe: 2018-11-12T00 2018-11-19T00
# loop
# GoogleTrends Call 47 of 53 : Timeframe: 2018-11-19T00 2018-11-26T00
# loop
# GoogleTrends Call 48 of 53 : Timeframe: 2018-11-26T00 2018-12-03T00
# loop
# GoogleTrends Call 49 of 53 : Timeframe: 2018-12-03T00 2018-12-10T00
# loop
# GoogleTrends Call 50 of 53 : Timeframe: 2018-12-10T00 2018-12-17T00
# loop
# GoogleTrends Call 51 of 53 : Timeframe: 2018-12-17T00 2018-12-24T00
False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-11-26 00:00:00       78      False
#  2018-11-26 01:00:00       77      False
#  2018-11-26 02:00:00       66      False
#  2018-11-26 03:00:00       77      False
#  2018-11-26 04:00:00       78      False
#  ...                      ...        ...
#  2018-12-02 20:00:00       48      False
#  2018-12-02 21:00:00       48      False
#  2018-12-02 22:00:00       49      False
#  2018-12-02 23:00:00       46      False
#  2018-12-03 00:00:00       50      False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-12-03 00:00:00       60      False
#  2018-12-03 01:00:00       52      False
#  2018-12-03 02:00:00       62      False
#  2018-12-03 03:00:00       59      False
#  2018-12-03 04:00:00       57      False
#  ...                      ...        ...
#  2018-12-09 20:00:00       58      False
#  2018-12-09 21:00:00       58      False
#  2018-12-09 22:00:00       68      False
#  2018-12-09 23:00:00       72      False
#  2018-12-10 00:00:00       61      False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-12-10 00:00:00       65      False
#  2018-12-10 01:00:00       62      False
#  2018-12-10 02:00:00       64      False
#  2018-12-10 03:00:00       66      False
#  2018-12-10 04:00:00       70      False
#  ...                      ...        ...
#  2018-12-16 20:00:00       60      False
#  2018-12-16 21:00:00       67      False
#  2018-12-16 22:00:00       70      False
#  2018-12-16 23:00:00       68      False
#  2018-12-17 00:00:00       67      False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-12-17 00:00:00       66      False
#  2018-12-17 01:00:00       60      False
#  2018-12-17 02:00:00       60      False
#  2018-12-17 03:00:00       64      False
#  2018-12-17 04:00:00       60      False
#  ...                      ...        ...
#  2018-12-23 20:00:00       62      False
#  2018-12-23 21:00:00       65      False
#  2018-12-23 22:00:00       64      False
#  2018-12-23 23:00:00       70      False
#  2018-12-24 00:00:00       64      False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-12-24 00:00:00       78      False
#  2018-12-24 01:00:00       80      False
#  2018-12-24 02:00:00       94      False
#  2018-12-24 03:00:00       78      False
#  2018-12-24 04:00:00       80      False
#  ...                      ...        ...
#  2018-12-30 20:00:00       61      False
#  2018-12-30 21:00:00       74      False
#  2018-12-30 22:00:00       67      False
#  2018-12-30 23:00:00       84      False
#  2018-12-31 00:00:00       76      False
#
#  [169 rows x 2 columns],
#                       bitcoin  isPartial
#  date
#  2018-12-31 00:00:00       83      False
#  2018-12-31 00:08:00       67      False
#  2018-12-31 00:16:00       79      False
#  2018-12-31 00:24:00       68      False
#  2018-12-31 00:32:00       66      False
#  ...                      ...        ...
#  2018-12-31 23:28:00       56      False
#  2018-12-31 23:36:00       60      False
#  2018-12-31 23:44:00       58      False
#  2018-12-31 23:52:00       59      False
#  2019-01-01 00:00:00       52      False
#
#  [181 rows x 2 columns]]

# %%
"""Now we have to rescale our weekly data. We can do this
by overlapping the weekly timeframes by one data point."""

#We define a ratio list, which includes the correction parameters =
#(scaling last hour of week i / scaling first hour of week i+1)
ratio_list = []

#here we apply the correction parameter to all dfs in the interest list except interest_list[0]
for i in range(len(interest_list)-1):
    #Calculation of the ratio
    ratio = float(interest_list[i][keyword_list[0]].iloc[-1])/float(interest_list[i+1][keyword_list[0]].iloc[0]) 
    ratio_list.append(ratio)
    print("{} of {}: Ratio = {}, Scale 1st hour of week {} = {}, scale last hour of week {} = {}"\
          .format(i+1, len(interest_list)-1, ratio_list[i],
                  i+1, float(interest_list[i+1][keyword_list[0]].iloc[0]),
                  i ,float(interest_list[i][keyword_list[0]].iloc[-1]),
                  )
          )
    #Multiply the ratio with the scales of week i+1
    #Therefore we add the column "Scale" and multiply times the value in ratio_list[i]
    #The make the calculations work for round i+1, we overwrite the values column of the df[keyword] with df["Scale"] in the interest list
    interest_list[0]["Scale_{}".format(keyword_list)] = interest_list[0][keyword_list[0]]
    interest_list[i+1]["Scale_{}".format(keyword_list)] = interest_list[i+1][keyword_list[0]].apply(lambda x:x*ratio_list[i])
    interest_list[i+1][keyword_list[0]] = interest_list[i+1]["Scale_{}".format(keyword_list)]
# Out:
# 1 of 52: Ratio = 1.3035714285714286, Scale 1st hour of week 1 = 56.0, scale last hour of week 0 = 73.0
# 2 of 52: Ratio = 2.3985714285714286, Scale 1st hour of week 2 = 25.0, scale last hour of week 1 = 59.964285714285715
# 3 of 52: Ratio = 0.8751544401544401, Scale 1st hour of week 3 = 74.0, scale last hour of week 2 = 64.76142857142857
# 4 of 52: Ratio = 1.208546607832322, Scale 1st hour of week 4 = 42.0, scale last hour of week 3 = 50.758957528957524
# 5 of 52: Ratio = 1.6919652509652507, Scale 1st hour of week 5 = 35.0, scale last hour of week 4 = 59.21878378378378
# 6 of 52: Ratio = 0.648972972972973, Scale 1st hour of week 6 = 73.0, scale last hour of week 5 = 47.37502702702702
# 7 of 52: Ratio = 0.5521113352158128, Scale 1st hour of week 7 = 67.0, scale last hour of week 6 = 36.991459459459456
# 8 of 52: Ratio = 0.41242051546241437, Scale 1st hour of week 8 = 83.0, scale last hour of week 7 = 34.230902783380394
# 9 of 52: Ratio = 0.5234568080869105, Scale 1st hour of week 9 = 52.0, scale last hour of week 8 = 27.21975402051935
# 10 of 52: Ratio = 0.514273355313456, Scale 1st hour of week 10 = 57.0, scale last hour of week 9 = 29.31358125286699
# 11 of 52: Ratio = 0.3815576507164351, Scale 1st hour of week 11 = 93.0, scale last hour of week 10 = 35.48486151662846
# 12 of 52: Ratio = 0.9326964795290635, Scale 1st hour of week 12 = 27.0, scale last hour of week 11 = 25.182804947284716
# 13 of 52: Ratio = 0.3981021558965515, Scale 1st hour of week 13 = 82.0, scale last hour of week 12 = 32.644376783517224
# 14 of 52: Ratio = 0.38566146352478425, Scale 1st hour of week 14 = 64.0, scale last hour of week 13 = 24.682333665586192
# 15 of 52: Ratio = 0.29567378870233463, Scale 1st hour of week 15 = 90.0, scale last hour of week 14 = 26.610640983210114
# 16 of 52: Ratio = 0.3548085464428015, Scale 1st hour of week 16 = 70.0, scale last hour of week 15 = 24.836598250996108
# 17 of 52: Ratio = 0.26167130300156616, Scale 1st hour of week 17 = 80.0, scale last hour of week 16 = 20.93370424012529
# 18 of 52: Ratio = 0.30131847012301555, Scale 1st hour of week 18 = 66.0, scale last hour of week 17 = 19.887019028119028
# 19 of 52: Ratio = 0.24459969927633024, Scale 1st hour of week 19 = 85.0, scale last hour of week 18 = 20.79097443848807
# 20 of 52: Ratio = 0.2709412053522427, Scale 1st hour of week 20 = 65.0, scale last hour of week 19 = 17.611178347895777
# 21 of 52: Ratio = 0.23707355468321234, Scale 1st hour of week 21 = 72.0, scale last hour of week 20 = 17.06929593719129
# 22 of 52: Ratio = 0.2921084870203866, Scale 1st hour of week 22 = 56.0, scale last hour of week 21 = 16.35807527314165
# 23 of 52: Ratio = 0.28850220940285093, Scale 1st hour of week 23 = 81.0, scale last hour of week 22 = 23.368678961630927
# 24 of 52: Ratio = 0.3106946870492241, Scale 1st hour of week 24 = 52.0, scale last hour of week 23 = 16.156123726559652
# 25 of 52: Ratio = 0.24209975614225251, Scale 1st hour of week 25 = 77.0, scale last hour of week 24 = 18.641681222953444
# 26 of 52: Ratio = 0.23172405230758458, Scale 1st hour of week 26 = 70.0, scale last hour of week 25 = 16.22068366153092
# 27 of 52: Ratio = 0.20354139729720266, Scale 1st hour of week 27 = 74.0, scale last hour of week 26 = 15.062063399992997
# 28 of 52: Ratio = 0.3612859802025347, Scale 1st hour of week 28 = 40.0, scale last hour of week 27 = 14.45143920810139
# 29 of 52: Ratio = 0.29276622533653673, Scale 1st hour of week 29 = 58.0, scale last hour of week 28 = 16.98044106951913
# 30 of 52: Ratio = 0.21957466900240258, Scale 1st hour of week 30 = 80.0, scale last hour of week 29 = 17.565973520192205
# 31 of 52: Ratio = 0.2650039108649686, Scale 1st hour of week 31 = 58.0, scale last hour of week 30 = 15.37022683016818
# 32 of 52: Ratio = 0.2650039108649686, Scale 1st hour of week 32 = 65.0, scale last hour of week 31 = 17.22525420622296
# 33 of 52: Ratio = 0.21754052384437722, Scale 1st hour of week 33 = 67.0, scale last hour of week 32 = 14.575215097573274
# 34 of 52: Ratio = 0.26829997940806527, Scale 1st hour of week 34 = 60.0, scale last hour of week 33 = 16.097998764483915
# 35 of 52: Ratio = 0.32100176107750666, Scale 1st hour of week 35 = 56.0, scale last hour of week 34 = 17.976098620340373
# 36 of 52: Ratio = 0.21667618872731698, Scale 1st hour of week 36 = 80.0, scale last hour of week 35 = 17.334095098185358
# 37 of 52: Ratio = 0.1938681688612836, Scale 1st hour of week 37 = 76.0, scale last hour of week 36 = 14.733980833457554
# 38 of 52: Ratio = 0.18862848862178944, Scale 1st hour of week 38 = 74.0, scale last hour of week 37 = 13.95850815801242
# 39 of 52: Ratio = 0.18146538145893668, Scale 1st hour of week 39 = 79.0, scale last hour of week 38 = 14.335765135255997
# 40 of 52: Ratio = 0.20456097546280133, Scale 1st hour of week 40 = 55.0, scale last hour of week 39 = 11.250853650454074
# 41 of 52: Ratio = 0.22079597351540461, Scale 1st hour of week 41 = 63.0, scale last hour of week 40 = 13.910146331470491
# 42 of 52: Ratio = 0.19664641391215723, Scale 1st hour of week 42 = 64.0, scale last hour of week 41 = 12.585370490378063
# 43 of 52: Ratio = 0.17077188576582075, Scale 1st hour of week 43 = 76.0, scale last hour of week 42 = 12.978663318202377
# 44 of 52: Ratio = 0.17520751916233557, Scale 1st hour of week 44 = 77.0, scale last hour of week 43 = 13.49097897549984
# 45 of 52: Ratio = 0.4069335928931665, Scale 1st hour of week 45 = 31.0, scale last hour of week 44 = 12.614941379688162
# 46 of 52: Ratio = 0.4182373038068656, Scale 1st hour of week 46 = 36.0, scale last hour of week 45 = 15.05654293704716
# 47 of 52: Ratio = 0.3431690697902487, Scale 1st hour of week 47 = 78.0, scale last hour of week 46 = 26.767187443639397
# 48 of 52: Ratio = 0.28597422482520723, Scale 1st hour of week 48 = 60.0, scale last hour of week 47 = 17.158453489512436
# 49 of 52: Ratio = 0.2683758109898099, Scale 1st hour of week 49 = 65.0, scale last hour of week 48 = 17.444427714337642
# 50 of 52: Ratio = 0.27244211115632216, Scale 1st hour of week 50 = 66.0, scale last hour of week 49 = 17.98117933631726
# 51 of 52: Ratio = 0.22354224505134127, Scale 1st hour of week 51 = 78.0, scale last hour of week 50 = 17.43629511400462
# 52 of 52: Ratio = 0.20468928462532454, Scale 1st hour of week 52 = 83.0, scale last hour of week 51 = 16.989210623901936

# %%
"""We now combine the dataframes in the interest list to a Pandas Dataframe.
The data has the correct scaling now. But not yet in the range of 0 and 100."""
df = pd.concat(interest_list)
df.drop(labels = keyword_list[0] , axis = 1, inplace = True)
df.drop(labels = "isPartial", axis = 1, inplace = True)
df.head(5)
# Out:
#                      Scale_['bitcoin']
# date
# 2018-01-01 00:00:00               71.0
# 2018-01-01 01:00:00               68.0
# 2018-01-01 02:00:00               69.0
# 2018-01-01 03:00:00               68.0
# 2018-01-01 04:00:00               67.0

# %%
"""As last step we scale the data back like google to a range between 0 and 100."""
max_interest = np.max(df["Scale_{}".format(keyword_list)])
df["Scale_{}".format(keyword_list)]=df["Scale_{}".format(keyword_list)]/max_interest*100

# %%
df
# Out:
#                      Scale_['bitcoin']
# date
# 2018-01-01 00:00:00          29.600953
# 2018-01-01 01:00:00          28.350208
# 2018-01-01 02:00:00          28.767123
# 2018-01-01 03:00:00          28.350208
# 2018-01-01 04:00:00          27.933294
# ...                                ...
# 2018-12-31 23:28:00           4.778928
# 2018-12-31 23:36:00           5.120280
# 2018-12-31 23:44:00           4.949604
# 2018-12-31 23:52:00           5.034942
# 2019-01-01 00:00:00           4.437576
#
# [8969 rows x 1 columns]

# %%
df.describe()
# Out:
#        Scale_['bitcoin']
# count        8969.000000
# mean           10.797204
# std             8.174407
# min             2.560140
# 25%             6.370003
# 50%             7.725903
# 75%            11.302710
# max           100.000000

# %%
plt.plot(df)

# %% [markdown]
# Done. The result shows the hourly google search volumne of the specified timeframe. Maybe there are daily, weekly or yearly patterns? Explore the data. Maybe you can later add the google trends feature as input parameter of an machine learning model for time series prediction.

# %%
import pandas as pd

c = pd.DataFrame(df)
c.to_csv("output.csv")

# %%
print(df)
# Out:
#                      Scale_['bitcoin']
# date
# 2018-01-01 00:00:00          29.600953
# 2018-01-01 01:00:00          28.350208
# 2018-01-01 02:00:00          28.767123
# 2018-01-01 03:00:00          28.350208
# 2018-01-01 04:00:00          27.933294
# ...                                ...
# 2018-12-31 23:28:00           4.778928
# 2018-12-31 23:36:00           5.120280
# 2018-12-31 23:44:00           4.949604
# 2018-12-31 23:52:00           5.034942
# 2019-01-01 00:00:00           4.437576
#
# [8969 rows x 1 columns]
