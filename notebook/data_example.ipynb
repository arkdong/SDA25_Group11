# %% [markdown]
# # Load Data Examples
# This Notebook illustrate how to import function to provide you the data that you might need.

# %%
import sys

# Get the path to the helper functions
sys.path.append('../src/')

import importlib
import read_data.helper as helper

# Reload helper functions
importlib.reload(helper)
# Out:
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ datetime            ┆ body                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2014-06-26 16:49:41 ┆ How do you feel about Bitcoin?… │
# │ 2014-05-17 23:30:36 ┆ [The guy who blew a huge porti… │
# └─────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ### Load 16M Bitcoin tweets

# %%
df = helper.load_16M_tweet(columns=["timestamp", "text"], csv_path="../data/tweets.csv")
print(df.head(2))

# %% [markdown]
# ### Load Bitcoin Tweets with Sentiment

# %%
df2 = helper.load_tweet_with_sentiment(columns=["date", "text", "sentiment"], csv_path="../data/tweets_sentiment.csv")
print(df2.head(2))

# %% [markdown]
# ### Load Reddit comment with Bitcoin

# %%
df3 = helper.load_reddit_comments(columns=["datetime", "body"], csv_path="../data/reddit_bitcoin.csv")
print(df3.head(2))
