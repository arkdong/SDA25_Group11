# %% [markdown]
# # Load Data Examples
# This Notebook illustrate how to import function to provide you the data that you might need.

# %%
import sys

# Get the path to the helper functions
sys.path.append('../src/')

import importlib
import helper.data as data

# Reload helper functions
importlib.reload(data)
# Out:
# <module 'helper.data' from '/Users/rukundong/SDA25_Group11/notebook/../src/helper/data.py'>

# %% [markdown]
# ### Load 16M Bitcoin tweets

# %%
df = data.load_16M_tweet(columns=["timestamp", "text"], csv_path="../data/tweets.csv")
print(df.head(2))
# Out:
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ timestamp           ┆ text                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2019-05-27 11:49:14 ┆ È appena uscito un nuovo video… │
# │ 2019-05-27 11:49:18 ┆ Cardano: Digitize Currencies; … │
# └─────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ### Load Bitcoin Tweets with Sentiment

# %%
df2 = data.load_tweet_with_sentiment(columns=["date", "text", "sentiment"], csv_path="../data/tweets_sentiment.csv")
print(df2.head(2))
# Out:
# shape: (2, 3)
# ┌─────────────────────┬─────────────────────────────────┬───────────┐
# │ date                ┆ text                            ┆ sentiment │
# │ ---                 ┆ ---                             ┆ ---       │
# │ datetime[μs]        ┆ str                             ┆ str       │
# ╞═════════════════════╪═════════════════════════════════╪═══════════╡
# │ 2019-05-27 00:00:00 ┆ È appena uscito un nuovo video… ┆ Positive  │
# │ 2019-05-27 00:00:00 ┆ Cardano: Digitize Currencies; … ┆ Positive  │
# └─────────────────────┴─────────────────────────────────┴───────────┘

# %% [markdown]
# ### Load Reddit comment with Bitcoin

# %%
df3 = data.load_reddit_comments(columns=["timestamp", "text"], csv_path="../data/reddit_bitcoin.csv")
print(df3.head(2))
# Out:
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ timestamp           ┆ text                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2014-06-26 16:49:41 ┆ How do you feel about Bitcoin?… │
# │ 2014-05-17 23:30:36 ┆ [The guy who blew a huge porti… │
# └─────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ### Load Reddit and Twitter data from 1 Jan 2018 to 1 Jan 2019

# %%
df4 = data.load_timestamp_text_2018_2019(csv_path="../data/reddit_2018_2019.csv")
print(df4.head(2))
df5 = data.load_timestamp_text_2018_2019(csv_path="../data/tweets_2018_2019.csv")
print(df5.head(2))
# Out:
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ timestamp           ┆ text                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2018-09-03 09:02:05 ┆ &gt;[– Det er ingen grunn til … │
# │ 2018-09-16 00:56:14 ┆ Yes, but that's because I got … │
# └─────────────────────┴─────────────────────────────────┘
# shape: (2, 2)
# ┌─────────────────────┬─────────────────────────────────┐
# │ timestamp           ┆ text                            │
# │ ---                 ┆ ---                             │
# │ datetime[μs]        ┆ str                             │
# ╞═════════════════════╪═════════════════════════════════╡
# │ 2018-09-11 05:46:06 ┆ I didnt tether at $7300 #iamsp… │
# │ 2018-12-29 04:39:39 ┆ The first lab made diamond hap… │
# └─────────────────────┴─────────────────────────────────┘

# %% [markdown]
# ### Load all Bitcoin Price

# %%
df6 = data.load_btc(csv_path="../data/btc.csv")
print(df6.head(2))
# Out:
# shape: (2, 6)
# ┌─────────────────────┬──────┬──────┬──────┬───────┬────────┐
# │ timestamp           ┆ open ┆ high ┆ low  ┆ close ┆ volume │
# │ ---                 ┆ ---  ┆ ---  ┆ ---  ┆ ---   ┆ ---    │
# │ datetime[μs]        ┆ f64  ┆ f64  ┆ f64  ┆ f64   ┆ f64    │
# ╞═════════════════════╪══════╪══════╪══════╪═══════╪════════╡
# │ 2012-01-01 10:01:00 ┆ 4.58 ┆ 4.58 ┆ 4.58 ┆ 4.58  ┆ 0.0    │
# │ 2012-01-01 10:02:00 ┆ 4.58 ┆ 4.58 ┆ 4.58 ┆ 4.58  ┆ 0.0    │
# └─────────────────────┴──────┴──────┴──────┴───────┴────────┘

# %% [markdown]
# ### Load Bitcoin data from 1 Jan 2018 to 1 Jan 2019

# %%
df7 = data.load_btc_2018_2019(csv_path="../data/btc_2018_2019.csv")
print(df7.head(2))
# Out:
# shape: (2, 6)
# ┌─────────────────────┬──────────┬──────────┬──────────┬──────────┬───────────┐
# │ timestamp           ┆ open     ┆ high     ┆ low      ┆ close    ┆ volume    │
# │ ---                 ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---       │
# │ datetime[μs]        ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64       │
# ╞═════════════════════╪══════════╪══════════╪══════════╪══════════╪═══════════╡
# │ 2018-01-01 00:00:00 ┆ 13840.53 ┆ 13840.53 ┆ 13819.04 ┆ 13820.96 ┆ 1.045522  │
# │ 2018-01-01 00:01:00 ┆ 13821.05 ┆ 13888.9  ┆ 13821.05 ┆ 13850.67 ┆ 18.083867 │
# └─────────────────────┴──────────┴──────────┴──────────┴──────────┴───────────┘
